# %% [markdown]
# ---
# title: "Assignment: Hypothesis Testing for Business Analytics"
# subtitle: "TechTrends Data Analysis"
# author: "Dr. Smith"
# institute: "University of South Florida"
# format:
#   html:
#     embed-resources: true
#     toc: true
#     toc-location: left
#     toc-depth: 2
#     number-sections: false
#     highlight-style: github
#     code-fold: false
#     code-tools: true
#     code-block-bg: "#f5f5f5"
#     code-block-border-left: "#31BAE9"
#     code-block-line-numbers: false
#     code-overflow: scroll
#     theme:
#       light: flatly
#       dark: darkly
#     callout-appearance: simple
#     self-contained: true
#     code-line-numbers: true
#     sidebar-width: 250px
#     body-width: 800px
#     margin-width: 250px
#     gutter-width: 1.5em
# execute:
#   echo: true
#   warning: false
# ---
#
# # Overview
#
# In this assignment, you will build upon last week’s analysis of TechTrends—our fictional e-commerce company—and use the same datasets to answer business questions with hypothesis testing and confidence interval estimation. You will work with the following datasets:
#
# - **sales-data.csv:** Monthly sales and marketing data for 2023 and 2024.
# - **product-performance.csv:** Performance metrics for various product categories.
#
# # Learning Objectives
#
# By completing this assignment, you will demonstrate your ability to:
# - Formulate and test statistical hypotheses based on business data.
# - Use one-sample, two-sample, and paired t‑tests to compare means.
# - Compute and interpret 95% confidence intervals.
# - Apply these statistical methods to real-world business scenarios, supporting decision-making for TechTrends.
#
# # Instructions
#
# 1. Download the datasets from the course website.
# 2. Work through the tasks below, ensuring your code runs without errors.
# 3. Submit your completed Jupyter notebook (.ipynb) or Python script (.py) file along with a brief report (1-2 pages) summarizing your findings.
# 4. Clearly comment your code and include markdown cells that explain your approach and interpretations.
#
# # Tasks
#
# ## Task 1: Sales Performance Analysis Using Hypothesis Testing
#
# TechTrends management is interested in understanding whether their sales targets are being met.
#
# 1. **One-Sample T‑Test on 2024 Sales:**
#    - **Objective:** Test if the average monthly sales in 2024 are significantly different from a benchmark of \$650,000.
#    - **Data:** Use the `sales-data.csv` file and filter for records from 2024.
#    - **Requirements:**
#      - Calculate the mean monthly sales for 2024.
#      - Perform a one-sample t‑test comparing the sample mean to \$650,000.
#      - Interpret the t‑statistic and p‑value.
#
# 2. **Two-Sample T‑Test Comparing 2023 and 2024 Sales:**
#    - **Objective:** Determine if there is a statistically significant difference between average monthly sales in 2023 and 2024.
#    - **Data:** Use the `sales-data.csv` file.
#    - **Requirements:**
#      - Compute the average monthly sales for each year.
#      - Conduct a two-sample t‑test to compare the two means.
#      - Explain the business implications of your findings.
#
# ---
#
# ## Task 2: Product Performance Evaluation
#
# TechTrends is evaluating the profitability and performance of its product categories.
#
# 1. **One-Sample T‑Test on Profit Margin:**
#    - **Objective:** Test if the average profit margin for the *Laptops* category is significantly different from a benchmark of 30%.
#    - **Data:** Use the `product-performance.csv` file.
#    - **Requirements:**
#      - Filter the data for the *Laptops* category.
#      - Perform a one-sample t‑test against the 30% benchmark.
#      - Discuss what a significant result means for product strategy.
#
# 2. **Two-Sample T‑Test on ROI Between Categories:**
#    - **Objective:** Compare the average Return on Investment (ROI) between *Laptops* and *Smartphones*.
#    - **Data:** Use the `product-performance.csv` file.
#    - **Requirements:**
#      - Extract ROI data for both categories.
#      - Conduct a two-sample t‑test to assess differences in ROI.
#      - Explain the potential business actions based on the result.
#
#
# ---
#
#
# # Submission Requirements
#
# Your submission should include:
# - A well-organized Jupyter notebook or Python script with:
#   - Clear markdown explanations of your approach.
#   - Code cells with the statistical analysis.
#   - Output from hypothesis tests and confidence intervals.
# - A brief written report (1-2 pages) summarizing your findings and their business implications.
#
# Be sure to follow best practices for code documentation and statistical interpretation.
#
# Happy analyzing, and I look forward to reviewing your insights!
