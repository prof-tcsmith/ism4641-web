# %% [markdown]
# # Week 9: Descriptive Statistics Practice
#
# ## Practice Problems
#
# Dr. Smith
# University of South Florida
# August 2025
#
# ---
#
# ## Instructions
#
# This notebook contains practice problems covering the four main topics from Week 9:
#
# 1. **Central Tendency** - Mean, median, mode
# 2. **Measures of Variability** - Range, variance, standard deviation, IQR, CV
# 3. **Distribution Visualization** - Histograms, box plots, density plots
# 4. **Correlation Analysis** - Pearson correlation, scatter plots, heatmaps
#
# Each topic has **2 practice problems** with starter code provided. Complete the code cells to solve each problem.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Set random seed for reproducibility
np.random.seed(42)

# Display settings
# %matplotlib inline
plt.style.use('default')
sns.set_palette("husl")

print("Libraries imported successfully!")

# %% [markdown]
# ---
#
# ## Part 1: Central Tendency (2 Problems)
#
# ### Problem 1.1: E-commerce Transaction Analysis
#
# **Scenario**: You have transaction amounts from 20 online customers.
#
# **Tasks**:
# 1. Calculate the mean, median, and mode
# 2. Determine which measure best represents "typical" customer spending
# 3. Identify if there are outliers affecting the mean
# 4. Create a histogram with mean and median lines

# %%
# Problem 1.1 Data
transaction_amounts = [25, 30, 35, 28, 45, 50, 32, 38, 42, 29, 
                       31, 48, 36, 33, 40, 27, 350, 34, 37, 41]

# Task 1: Calculate central tendency measures
mean_amount = # YOUR CODE HERE
median_amount = # YOUR CODE HERE
# For mode, you may need to use scipy.stats.mode or check for the most common value

# Task 2: Print results
print("Central Tendency Analysis")
print("="*50)
# YOUR CODE HERE

# Task 3: Identify outliers
# Hint: Values far from the mean or median might be outliers
# YOUR CODE HERE

# Task 4: Create visualization
# YOUR CODE HERE - create histogram with mean and median lines

# %% [markdown]
# ### Problem 1.2: Regional Sales Comparison
#
# **Scenario**: You have daily sales data for three regions.
#
# **Tasks**:
# 1. Calculate mean and median sales for each region
# 2. Identify which region has the highest average sales
# 3. Determine which region has the most consistent sales (mean vs median)
# 4. Create a grouped bar chart comparing means across regions

# %%
# Problem 1.2 Data
sales_data = pd.DataFrame({
    'Region': ['North']*15 + ['South']*15 + ['East']*15,
    'Daily_Sales': list(np.random.normal(15000, 2000, 15)) + 
                   list(np.random.normal(18000, 3000, 15)) + 
                   list(np.random.normal(12000, 1500, 15))
})

# Task 1: Calculate statistics by region
# YOUR CODE HERE - use groupby

# Task 2: Identify highest average
# YOUR CODE HERE

# Task 3: Assess consistency
# YOUR CODE HERE

# Task 4: Create visualization
# YOUR CODE HERE

# %% [markdown]
# ---
#
# ## Part 2: Measures of Variability (2 Problems)
#
# ### Problem 2.1: Product Quality Consistency
#
# **Scenario**: Compare widget weights from two manufacturing lines.
#
# **Tasks**:
# 1. Calculate range, variance, standard deviation, and CV for both lines
# 2. Determine which line is more consistent
# 3. Create side-by-side box plots
# 4. Calculate what percentage of Line A data falls within ±1 standard deviation of mean

# %%
# Problem 2.1 Data
line_A = [100.2, 99.8, 100.5, 100.1, 99.9, 100.3, 100.0, 99.7, 100.4, 100.2,
          99.8, 100.1, 100.3, 99.9, 100.0, 100.2, 99.8, 100.4, 100.1, 99.9]

line_B = [98.5, 101.2, 99.3, 102.1, 97.8, 100.5, 99.1, 101.8, 98.2, 102.5,
          99.7, 100.8, 98.9, 101.5, 99.4, 100.2, 98.7, 101.9, 99.2, 100.6]

# Task 1: Calculate variability measures
# YOUR CODE HERE - calculate for both Line A and Line B

# Task 2: Compare consistency
# YOUR CODE HERE - which has lower CV?

# Task 3: Create box plots
# YOUR CODE HERE

# Task 4: Calculate percentage within ±1 std dev
# YOUR CODE HERE

# %% [markdown]
# ### Problem 2.2: Outlier Detection Using IQR
#
# **Scenario**: Analyze customer purchase amounts and identify outliers.
#
# **Tasks**:
# 1. Calculate Q1, Q3, and IQR
# 2. Determine outlier bounds using the IQR method (Q1 - 1.5×IQR and Q3 + 1.5×IQR)
# 3. Identify which purchase amounts are outliers
# 4. Create a box plot showing the outliers

# %%
# Problem 2.2 Data
purchase_amounts = [45, 52, 48, 55, 60, 58, 51, 49, 53, 47, 150, 56, 50, 54, 
                    62, 48, 52, 10, 58, 55, 51, 59, 48, 52, 200, 56, 50, 54, 61]

# Task 1: Calculate Q1, Q3, and IQR
# YOUR CODE HERE

# Task 2: Calculate outlier bounds
# YOUR CODE HERE

# Task 3: Identify outliers
# YOUR CODE HERE

# Task 4: Create box plot
# YOUR CODE HERE

# %% [markdown]
# ---
#
# ## Part 3: Distribution Visualization (2 Problems)
#
# ### Problem 3.1: Employee Salary Distribution
#
# **Scenario**: Analyze salary distribution in a company.
#
# **Tasks**:
# 1. Create a histogram showing salary distribution
# 2. Create a box plot showing quartiles
# 3. Create a density plot
# 4. Compare mean vs median - what does this tell you about the distribution?

# %%
# Problem 3.1 Data
salaries = np.random.lognormal(11, 0.4, 100) * 1000  # Creates right-skewed distribution

# Task 1: Create histogram
# YOUR CODE HERE

# Task 2: Create box plot
# YOUR CODE HERE

# Task 3: Create density plot
# YOUR CODE HERE

# Task 4: Interpret mean vs median
# YOUR CODE HERE

# %% [markdown]
# ### Problem 3.2: Comparing Multiple Groups
#
# **Scenario**: Compare customer satisfaction scores across three store locations.
#
# **Tasks**:
# 1. Create side-by-side box plots for the three locations
# 2. Calculate percentiles (25th, 50th, 75th) for each location
# 3. Identify which location has the most consistent scores
# 4. Create overlaid density plots for all three locations

# %%
# Problem 3.2 Data
satisfaction_data = pd.DataFrame({
    'Location': ['Downtown']*30 + ['Suburban']*30 + ['Mall']*30,
    'Satisfaction_Score': list(np.random.normal(7.5, 1.2, 30)) + 
                         list(np.random.normal(8.2, 0.8, 30)) + 
                         list(np.random.normal(7.0, 1.5, 30))
})

# Task 1: Create box plots
# YOUR CODE HERE

# Task 2: Calculate percentiles
# YOUR CODE HERE - use groupby and quantile

# Task 3: Identify most consistent
# YOUR CODE HERE - look at IQR or std dev

# Task 4: Create overlaid density plots
# YOUR CODE HERE

# %% [markdown]
# ---
#
# ## Part 4: Correlation Analysis (2 Problems)
#
# ### Problem 4.1: Student Performance Analysis
#
# **Scenario**: Analyze relationships in student performance data.
#
# **Tasks**:
# 1. Calculate the correlation matrix
# 2. Create a correlation heatmap
# 3. Identify the strongest positive and negative correlations
# 4. Create scatter plots for the two strongest correlations
# 5. Interpret what these correlations mean for student success

# %%
# Problem 4.1 Data
n = 50
student_data = pd.DataFrame({
    'Study_Hours': np.random.uniform(5, 40, n),
    'Attendance_Pct': np.random.uniform(60, 100, n),
    'Sleep_Hours': np.random.uniform(4, 9, n),
    'Social_Media_Hours': np.random.uniform(0, 6, n)
})

# Exam score with realistic correlations
student_data['Exam_Score'] = (
    student_data['Study_Hours'] * 1.5 +
    student_data['Attendance_Pct'] * 0.5 +
    student_data['Sleep_Hours'] * 2 -
    student_data['Social_Media_Hours'] * 3 +
    np.random.normal(0, 10, n)
).clip(0, 100)

# Task 1: Calculate correlation matrix
# YOUR CODE HERE

# Task 2: Create heatmap
# YOUR CODE HERE

# Task 3: Identify strongest correlations
# YOUR CODE HERE

# Task 4: Create scatter plots
# YOUR CODE HERE

# Task 5: Interpret findings
# YOUR CODE HERE - write your interpretation

# %% [markdown]
# ### Problem 4.2: Marketing Campaign Effectiveness
#
# **Scenario**: Analyze the relationship between marketing spend and various business metrics.
#
# **Tasks**:
# 1. Calculate correlations between marketing spend and other metrics
# 2. Create scatter plots with trend lines for:
#    - Marketing Spend vs Sales
#    - Marketing Spend vs Customer Acquisition
# 3. Calculate the correlation coefficient for each relationship
# 4. Determine if marketing spend is effectively driving results
# 5. Identify which metric has the strongest relationship with marketing spend

# %%
# Problem 4.2 Data
n_campaigns = 40
marketing_data = pd.DataFrame({
    'Marketing_Spend': np.random.uniform(5000, 50000, n_campaigns),
})

# Create related metrics
marketing_data['Sales'] = (
    marketing_data['Marketing_Spend'] * 3.5 + 
    np.random.normal(0, 20000, n_campaigns)
)

marketing_data['New_Customers'] = (
    marketing_data['Marketing_Spend'] * 0.02 + 
    np.random.normal(0, 50, n_campaigns)
).clip(0)

marketing_data['Website_Traffic'] = (
    marketing_data['Marketing_Spend'] * 0.5 + 
    np.random.normal(0, 1000, n_campaigns)
).clip(0)

# Task 1: Calculate correlations
# YOUR CODE HERE

# Task 2: Create scatter plots with trend lines
# YOUR CODE HERE

# Task 3: Calculate correlation coefficients
# YOUR CODE HERE

# Task 4: Evaluate effectiveness
# YOUR CODE HERE

# Task 5: Identify strongest relationship
# YOUR CODE HERE

# %% [markdown]
# ---
#
# ## Summary
#
# Congratulations on completing the Week 9 practice problems! You've practiced:
#
# ✓ **Central Tendency**: Mean, median, mode
# ✓ **Variability**: Range, variance, standard deviation, IQR, CV
# ✓ **Distribution Visualization**: Histograms, box plots, density plots
# ✓ **Correlation Analysis**: Correlation matrices, heatmaps, scatter plots
#
# Review the solutions notebook to check your work and see detailed explanations for each problem.
